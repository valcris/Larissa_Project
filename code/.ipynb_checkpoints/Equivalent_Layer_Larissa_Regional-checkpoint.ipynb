# %% [markdown]
# ### Characterizing the problem of existence of a regional  in the equivalent layer
#
# ###  The regional is represented by an additive constant or first- or second-order polynomial  surfaces to the data. - By Valeria CF Barbosa.
# #### Larissa's Thesis

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.mlab as mlab
import cPickle as pickle
import datetime
from IPython.display import Markdown as md
from IPython.display import display as dp
import string as st

from __future__ import division
from future.builtins import super

import auxiliary_functions as af

import fatiando
from fatiando import gridder
from fatiando.mesher import Prism, PointGrid
from fatiando.gridder import regular
from fatiando.gravmag import prism, sphere
from fatiando.gravmag.eqlayer import EQLTotalField
from fatiando.gravmag.eqlayer import EQLGravity
from fatiando.inversion.regularization import Damping, Smoothness2D
from fatiando.inversion.hyper_param import LCurve
from fatiando.vis import mpl, myv
from fatiando.utils import ang2vec, vec2ang, contaminate, dircos
from fatiando.constants import G, SI2MGAL,SI2EOTVOS
# Out:
# C:\Users\valeria\Anaconda2\lib\site-packages\fatiando\vis\mpl.py:70: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")
# C:\Users\valeria\Anaconda2\lib\site-packages\fatiando\vis\myv.py:53: UserWarning: This module will be removed in v0.7.
#   warnings.warn("This module will be removed in v0.7.")

# %%
from numpy import linalg
from scipy.optimize import nnls
from scipy.sparse import identity
from scipy.sparse import diags
from scipy.stats import norm

# %%
# gz component of a point of mass located at xk, yk, zk computed at the observation point xi, yi, zi
def AZ(xi,yi,zi,xk,yk,zk):
    raio = 1.0
    volume = 1.0 
    rz = zi-zk
    rx = xi-xk
    ry = yi-yk
    r  = np.sqrt(rx**2+ry**2+rz**2)
    r3=r**3
    gz = -volume*G*rz/r3
    Az = gz*SI2MGAL
    return Az

# %%
# FTG - second derivatives of a point of mass located at xk, yk, zk computed at the observation point xi, yi, zi

def A_DERIVES(xi,yi,zi,xk,yk,zk):
    volume = 1.0 
    rx = xi-xk
    ry = yi-yk
    rz = zi-zk
    r  = np.sqrt(rx**2+ry**2+rz**2)
    r3=r**3
    r5=r**5
    
    gxx = volume*G*( (-1./r3)  + 3.*(rx*rx/r5) )
    gxy = volume*G*( (3.*rx*ry)/r5 )
    gxz = volume*G*( (3.*rx*rz)/r5 )
    gyy = volume*G*( (-1./r3)  + 3.*(ry*ry/r5) )
    gyz = volume*G*( (3.*ry*rz)/r5 )
    gzz = volume*G*( (-1./r3)  + 3.*(rz*rz/r5) )
    
    AXX = gxx*SI2EOTVOS
    AXY = gxy*SI2EOTVOS
    AXZ = gxz*SI2EOTVOS
    AYY = gyy*SI2EOTVOS
    AYZ = gyz*SI2EOTVOS
    AZZ = gzz*SI2EOTVOS
    
    return AXX, AXY, AXZ, AYY, AYZ, AZZ

# %%
# First-order polynomial surface

def Polynomial_1th(xp,yp,coef):
    assert (xp.size == yp.size), 'xp and yp must have the same size '
    assert (len(coef) == 3), 'First-order polynomial must have 3 coefficients '
    
    Poly_1th = coef[0] + np.dot(xp, coef[1]) + np.dot(yp, coef[2]) 
    
    return Poly_1th

# Second-order polynomial surface
def Polynomial_2th(xp,yp,coef):
    assert (xp.size == yp.size), 'xp and yp must have the same size '
    assert (len(coef) == 6), 'Secon-order polynomial must have 6 coefficients '
    
    Poly_2th = coef[0] + np.dot(xp, coef[1]) + np.dot(yp, coef[2]) + np.dot(xp*xp, coef[3]) \
                       + np.dot(xp*yp, coef[4]) + np.dot(yp*yp, coef[5])
   
    return Poly_2th

# %%
notebook_name = 'Equivalent_Layer_Larissa_Regional_.ipynb'

# %%
print("Version of Fatiando a Terra used: {}".format(fatiando.__version__))
# Out:
# Version of Fatiando a Terra used: ac2afbcb2d99b18f145cc1ed40075beb5f92dd5a

# %% [markdown]
# # Load the synthetic model formed by one prism

# %%
with open('../data/model_single.pickle') as f:
        full_model = pickle.load(f)

# %% [markdown]
# ##  Load the grid of points

# %%
with open('../data/regular_grid.pickle') as f:
        regular_grid = pickle.load(f)

# %% [markdown]
# ## Define the horizontal coordinates (xp, yp) and the vertical coordinate (zp) of the observation surface

# %%
#coordinates x and y of the data
xp, yp = regular(regular_grid['area'], regular_grid['shape'])


#vertical coordinates of the data 
#zp = af.observation_surface(xp,yp)

# vertical coordinates of the data
zp = np.zeros_like(xp)
height_obs = -50.



assert (xp.size == regular_grid['N']) and (yp.size == regular_grid['N']) and (zp.size == regular_grid['N']),  \
                'xp and yp and zp must have the same size defined by shape'

# %%
regular_grid
# Out:
# {'DS': 40915.483953458635,
#  'N': 8000,
#  'area': [-10000, 10000, -8000, 8000],
#  'metadata': 'Generated by computation_points.ipynb on 30 May 2018 17:31:52 UTC',
#  'shape': (100, 80),
#  'spacing': [202.02020202020202, 202.53164556962025]}

# %% [markdown]
# ### Noise-corrupted observations of vertical component ($g_z$) of the gravitational attraction.

# %%
ruido_percent = 0.001

# %%
data, std_noise = contaminate(prism.gz(xp,yp,zp,full_model['model']), ruido_percent, percent=True, seed=47, return_stddev=True)

# %%
print 'standard deviation used to contaminate the data %.5f' %std_noise, 'mGal'
# Out:
# standard deviation used to contaminate the data 0.00936 mGal

# %% [markdown]
# ## Defining  a Regional Background

# %%
#  Test without  Regional 
Regional_Information =  None 

#  Test with a Constant Regional given by variable "Regional" 
Regional_Information = 'CONSTANT'
Regional = 10.

#  Test with a first-order Regional 
Regional_Information = 'FIRST-ORDER POLYNOMIAL'

#  Test with a second-order Regional 
Regional_Information = 'SECOND-ORDER POLYNOMIAL'


print("REGIONAL INFORMATION ADDED TO THE ORIGINAL DATA WAS: {}".format(Regional_Information))
# Out:
# REGIONAL INFORMATION ADDED TO THE ORIGINAL DATA WAS: SECOND-ORDER POLYNOMIAL

# %%
if Regional_Information is not None: 
    if 'CONSTANT' in Regional_Information:
        print '\n'+Regional_Information+'  =  %4.3f \n' %Regional
    elif 'FIRST-ORDER POLYNOMIAL' in Regional_Information:
        coef_1th= [10., 0.0001, 0.0001]
        Regional = Polynomial_1th(xp,yp,coef_1th)
        print '\n'+Regional_Information+' with coefficients:   \n'
        print coef_1th
    elif 'SECOND-ORDER POLYNOMIAL'in Regional_Information:
        coef_2th= [10, 0.00000001, 0.00000001, 0.00000001, 0.00000001, 0.00000001]
        Regional = Polynomial_2th(xp,yp,coef_2th)
        print '\n'+Regional_Information+' with coefficients: \n' 
        print coef_2th
else:
    print '\n Data Without Regional Background \n'
# Out:
# SECOND-ORDER POLYNOMIAL with coefficients:
#
# [10, 1e-08, 1e-08, 1e-08, 1e-08, 1e-08]

# %% [markdown]
# ## Adding a Regional Background

# %%
if Regional_Information is None:
    gz = np.copy(data) 
else: 
    gz = np.copy(data) + Regional

# %% [markdown]
# ### Ploting 1) Original Data 2) Regional and 3) Data+Regional

# %%
file_name = '..\\figs\\Observed_Gz'

plt.figure(figsize=(18, 6))
unit = 'mGal'

if (Regional_Information is None):
    print 'Data Without Regional Background'
    print '\n No regional map \n '
    levels = mpl.contourf(yp, xp, gz, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, gz, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)
    ax1 = plt.gca() 
    mpl.m2km()

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax1.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax1.set_ylabel('x (km)')
    ax1.set_xlabel('y (km)')
    ax1.set_title('Noise-corrupted $g_z$ component ' )
    mpl.m2km()

elif ('CONSTANT' in Regional_Information):
    print("REGIONAL INFORMATION ADDED TO THE ORIGINAL DATA WAS: {}".format(Regional_Information))
    print '\n'+Regional_Information+'  =  %4.3f \n' %Regional
    print '\n No regional map \n '
    
    ax1=plt.subplot(1,2,1)
    ax1.text(0.05, 1.10,'(a) Noise-corrupted $g_z$ component',
        horizontalalignment='left',
        verticalalignment='top',
        transform = ax1.transAxes)

    levels = mpl.contourf(yp, xp, data, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, data, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)
    mpl.m2km()

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax1.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax1.set_ylabel('x (km)')
    ax1.set_xlabel('y (km)')
    mpl.m2km()
   
    # Plot Data + Regional 
    ax2=plt.subplot(1,2,2)
    ax2.text(0.05, 1.1,"(b) Data + Regional (The Regional is a) {}".format(Regional_Information), 
         horizontalalignment='left',
         verticalalignment='top',
         transform = ax2.transAxes)

    levels = mpl.contourf(yp, xp, gz, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, gz, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax2.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax2.set_ylabel('x (km)')
    ax2.set_xlabel('y (km)')
    mpl.m2km()


elif('FIRST-ORDER POLYNOMIAL' in Regional_Information) or ('SECOND-ORDER POLYNOMIAL' in Regional_Information):

    ax1=plt.subplot(1,3,1)
    ax1.text(0.05, 1.1,'(a) Noise-corrupted $g_z$ component',
         horizontalalignment='left',
         verticalalignment='top',
         transform = ax1.transAxes)

    levels = mpl.contourf(yp, xp, data, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, data, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax1.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax1.set_ylabel('x (km)')
    ax1.set_xlabel('y (km)')
    mpl.m2km()
# Plot Regional 
    ax2=plt.subplot(1,3,2)
    ax2.text(-0.05, 1.1,"(b) REGIONAL IS A {}".format(Regional_Information), 
         horizontalalignment='left',
         verticalalignment='top',
         transform = ax2.transAxes)

    levels = mpl.contourf(yp, xp, Regional, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, Regional, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax1.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax2.set_ylabel('x (km)')
    ax2.set_xlabel('y (km)')
    mpl.m2km()

    # Plot Data + Regional 
    ax3=plt.subplot(1,3,3)
    ax3.text(0.05, 1.1,'(C)  Data + Regional ',
         horizontalalignment='left',
         verticalalignment='top',
         transform = ax3.transAxes)

    levels = mpl.contourf(yp, xp, gz, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, gz, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=1)
    cbar.set_label(unit)

    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax3.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax3.set_ylabel('x (km)')
    ax3.set_xlabel('y (km)')
    mpl.m2km()



plt.savefig(file_name+'.eps', dpi=600)

# %%
if (Regional_Information is None) or ('CONSTANT' in Regional_Information):
    print '\n No regional map \n '
else:
    file_name = '..\\figs\\Regional'
    plt.figure(figsize=(15, 6))
    unit = 'mGal'
    levels = mpl.contourf(yp, xp, Regional, regular_grid['shape'], 20, interp= True)
    cbar = plt.colorbar()
    mpl.contour(yp, xp, Regional, regular_grid['shape'], levels, clabel=False, interp=True)
    plt.plot(yp, xp, 'w.', markersize=2)
    cbar.set_label(unit)
    ax = plt.gca()
    for i, sq in enumerate(full_model['projection']):
        y1, y2, x1, x2 = sq
        xs_project = [x1, x1, x2, x2, x1]
        ys_project = [y1, y2, y2, y1, y1]
        projection_style = '-k'
        ax.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
    ax.set_ylabel('x (km)')
    ax.set_xlabel('y (km)')
    ax.set_title( "REGIONAL INFORMATION ADDED TO THE ORIGINAL DATA WAS: {}".format(Regional_Information)  )
    plt.savefig(file_name+'.eps', dpi=600)

# %% [markdown]
# ### Verifying the New Number of the Data given by the length of the variable gz

# %%
Npts = len(gz)
print 'number of data: Npts', Npts

assert (xp.size == Npts) and (yp.size == Npts) and (zp.size == Npts),  \
                'xp, yp and zp must have the same size defined by Npts'
# Out:
# number of data: Npts 8000

# %% [markdown]
# ### Classical Equivalent Layer

# %%
# creating the equivalent Layer x and y coordinates 

xs = np.copy(xp)
ys = np.copy(yp)

#horizontal plane containing the equivalent sources located at plano_fonte 
plano_fonte=400.
zs = np.zeros_like(zp) + plano_fonte

M_source= len(xs)

assert (xs.size == M_source) and (ys.size == M_source) and (zs.size == M_source),  \
                'xs, ys and zs must have the same size defined by M_source'

print 'number of the equivalent sources at the equivalent layer: M_source', M_source
# Out:
# number of the equivalent sources at the equivalent layer: M_source 8000

# %%
print len(xp), len(yp), len(zp), len(xs), len(ys), len(zs)
# Out:
# 8000 8000 8000 8000 8000 8000

# %% [markdown]
# ##### Creating the sensitivity matrix based on $g_z$ component of point of masses

# %%
A_GZ = np.empty((Npts,M_source),dtype = float)

for j in range(M_source):
    A_GZ[:,j] = AZ(xp, yp, zp, xs[j],ys[j],zs[j])

# %%
ATA = np.empty((M_source,M_source),dtype =float)
ATA = np.dot(A_GZ.T, A_GZ)

# Gradient
ATdo = np.dot(A_GZ.T,gz)

# %%
reg_parameter = 0.0000000000000000000001

# %%
Hessiana  = ATA + diags([reg_parameter], 0, (M_source,M_source), format='csr', dtype='float')

p_estimate = linalg.solve(Hessiana,ATdo)

# %%
gz_predicted    = np.dot(A_GZ,p_estimate)
residual        = gz - gz_predicted

# %%
file_name = '..\\figs\\Observed_And_Predicted_Gz'
plt.figure(figsize=(8, 6))


plt.subplot(2,1,1)
unit = 'mGal'
levels = mpl.contourf(yp, xp, gz, regular_grid['shape'], 20, interp= True)
cbar = plt.colorbar()
mpl.contour(yp, xp, gz, regular_grid['shape'], levels, clabel=False, interp=True)
plt.plot(yp, xp, 'w.', markersize=1)
cbar.set_label(unit)
ax = plt.gca()
for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-k'
    ax.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
ax.set_ylabel('x (km)')
ax.set_xlabel('y (km)')
ax.set_title(' Noise-corrupted gz component ')

plt.subplot(2,1,2)
unit = 'mGal'
levels = mpl.contourf(yp, xp, gz_predicted, regular_grid['shape'], 20, interp= True)
cbar = plt.colorbar()
mpl.contour(yp, xp, gz_predicted, regular_grid['shape'], levels, clabel=False, interp=True)
plt.plot(yp, xp, 'w.', markersize=1)
cbar.set_label(unit)
ax = plt.gca()
for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-k'
    ax.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
ax.set_ylabel('x (km)')
ax.set_xlabel('y (km)')
ax.set_title(' Predicted gz-component ')

plt.savefig(file_name+'.eps', dpi=600)

# %%
file_name = '..\\figs\\Residual_and_Histogram_Gz'
plt.figure(figsize=(8, 10))
plt.subplot(2,1,1)
unit = 'mGal'
levels = mpl.contourf(yp, xp, residual, regular_grid['shape'], 10, interp= True)
cbar = plt.colorbar()
#mpl.contour(yp, xp, residual, regular_grid['shape'], levels, clabel=False, interp=True)
plt.plot(yp, xp, 'w.', markersize=1)
cbar.set_label(unit)
ax = plt.gca()
for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-k'
    ax.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
ax.set_ylabel('x (km)')
ax.set_xlabel('y (km)')
ax.set_title(' Residual data ')

plt.subplot(2,1,2)

(mu, sigma) = norm.fit(residual)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(residual, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu, sigma)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
plt.xlabel('Difference between theObserved and the predicted data (mGal))')
plt.ylabel('Probability')
plt.title(r'$ \mu=%.3f,\ \sigma=%.3f$' %(mu, sigma))
plt.grid(True)

plt.savefig(file_name+'.eps', dpi=600)
#plt.show()
#mpl.savefig('res_histo_densi_estimada.png', pad_inches=0.0)

# %%
file_name = '..\\figs\\Estimated_Equivalent_Layer'
plt.figure(figsize=(8, 3))

unit = 'estimated mass'
levels = mpl.contourf(yp, xp, p_estimate, regular_grid['shape'], 10, interp= True)
cbar = plt.colorbar()
#mpl.contour(yp, xp, residual, regular_grid['shape'], levels, clabel=False, interp=True)
plt.plot(yp, xp, 'w.', markersize=1)
cbar.set_label(unit)
ax = plt.gca()
for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-k'
    ax.plot(xs_project, ys_project, projection_style,linewidth = 2.0 )
ax.set_ylabel('x (km)')
ax.set_xlabel('y (km)')
ax.set_title(' Estimated mass via Equivalent Layer ')

plt.savefig(file_name+'.eps', dpi=600)

# %% [markdown]
# ##  FTG calculated via Equivalent Layer

# %%
gxx_analitico = []
gxy_analitico = []
gxz_analitico = []
gyy_analitico = []
gyz_analitico = []
gzz_analitico = []

for i in range(Npts):
    gxx_analitico=np.append(gxx_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[0], p_estimate))
    gxy_analitico=np.append(gxy_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[1], p_estimate))
    gxz_analitico=np.append(gxz_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[2], p_estimate))
    gyy_analitico=np.append(gyy_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[3], p_estimate))
    gyz_analitico=np.append(gyz_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[4], p_estimate))
    gzz_analitico=np.append(gzz_analitico, np.dot(A_DERIVES(xp[i],yp[i],zp[i],xs,ys,zs)[5], p_estimate))

# %%
file_name = '..\\figs\\FTG_Estimated_EqLayer'


unit = 'Eotvos'
plt.figure(figsize=(12, 10))


#   $G_{xx}$
ax1=plt.subplot(3,3,1)
ax1.text(0, 1.10,'(a) $G_{xx}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax1.transAxes)


levels = mpl.contourf(yp, xp, gxx_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxx_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax1.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{xy}$

ax2=plt.subplot(3,3,2)
ax2.text(0, 1.10,'(b) $G_{xy}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax2.transAxes)


levels = mpl.contourf(yp, xp, gxy_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxy_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax2.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{xz}$

ax3=plt.subplot(3,3,3)
ax3.text(0, 1.10,'(c) $G_{xz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax3.transAxes)


levels = mpl.contourf(yp, xp, gxz_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxz_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax3.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{yy}$
ax4=plt.subplot(3,3,5)
ax4.text(0, 1.10,'(d) $G_{yy}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax4.transAxes)


levels = mpl.contourf(yp, xp, gyy_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gyy_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax4.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{yz}$
ax5=plt.subplot(3,3,6)
ax5.text(0, 1.10,'(e) $G_{yz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax5.transAxes)


levels = mpl.contourf(yp, xp, gyz_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gyz_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax5.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{zz}$
ax6=plt.subplot(3,3,9)
ax6.text(0, 1.10,'(f) $G_{zz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax6.transAxes)


levels = mpl.contourf(yp, xp, gzz_analitico, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gzz_analitico, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax6.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

plt.savefig(file_name+'.eps', dpi=600)

# %% [markdown]
# ##  TRUE FTG

# %%
gxx_true = []
gxy_true = []
gxz_true = []
gyy_true = []
gyz_true = []
gzz_true = []

gxx_true = prism.gxx(xp,yp,zp,full_model['model'])
gxy_true = prism.gxy(xp,yp,zp,full_model['model'])
gxz_true = prism.gxz(xp,yp,zp,full_model['model'])
gyy_true = prism.gyy(xp,yp,zp,full_model['model'])
gyz_true = prism.gyz(xp,yp,zp,full_model['model'])
gzz_true = prism.gzz(xp,yp,zp,full_model['model'])

# %%
file_name = '..\\figs\\FTG_TRUE'


unit = 'Eotvos'
plt.figure(figsize=(12, 10))


#   $G_{xx}$
ax1=plt.subplot(3,3,1)
ax1.text(0, 1.10,'(a) $G_{xx}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax1.transAxes)


levels = mpl.contourf(yp, xp, gxx_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxx_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax1.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{xy}$

ax2=plt.subplot(3,3,2)
ax2.text(0, 1.10,'(b) $G_{xy}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax2.transAxes)


levels = mpl.contourf(yp, xp, gxy_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxy_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax2.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{xz}$

ax3=plt.subplot(3,3,3)
ax3.text(0, 1.10,'(c) $G_{xz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax3.transAxes)


levels = mpl.contourf(yp, xp, gxz_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gxz_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax3.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{yy}$
ax4=plt.subplot(3,3,5)
ax4.text(0, 1.10,'(d) $G_{yy}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax4.transAxes)


levels = mpl.contourf(yp, xp, gyy_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gyy_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax4.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{yz}$
ax5=plt.subplot(3,3,6)
ax5.text(0, 1.10,'(e) $G_{yz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax5.transAxes)


levels = mpl.contourf(yp, xp, gyz_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gyz_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax5.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{zz}$
ax6=plt.subplot(3,3,9)
ax6.text(0, 1.10,'(f) $G_{zz}$',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax6.transAxes)


levels = mpl.contourf(yp, xp, gzz_true, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
mpl.contour(yp, xp, gzz_true, regular_grid['shape'], levels, clabel=False, interp=True)
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax6.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

plt.savefig(file_name+'.eps', dpi=600)

# %% [markdown]
# ### FTG RESIDUALS

# %%
res_gxx= gxx_true - gxx_analitico
res_gxy= gxy_true - gxy_analitico
res_gxz= gxz_true - gxz_analitico
res_gyy= gyy_true - gyy_analitico
res_gyz= gyz_true - gyz_analitico
res_gzz= gzz_true - gzz_analitico

# %%
file_name = '..\\figs\\FTG_RESIDUALS'


unit = 'Eotvos'
plt.figure(figsize=(12, 10))


#   $G_{xx}$
ax1=plt.subplot(3,3,1)
ax1.text(0, 1.10,'(a) $G_{xx}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax1.transAxes)


levels = mpl.contourf(yp, xp, res_gxx, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax1.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{xy}$

ax2=plt.subplot(3,3,2)
ax2.text(0, 1.10,'(b) $G_{xy}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax2.transAxes)


levels = mpl.contourf(yp, xp, res_gxy, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax2.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{xz}$

ax3=plt.subplot(3,3,3)
ax3.text(0, 1.10,'(c) $G_{xz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax3.transAxes)


levels = mpl.contourf(yp, xp, res_gxz, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax3.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{yy}$
ax4=plt.subplot(3,3,5)
ax4.text(0, 1.10,'(d) $G_{yy}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax4.transAxes)


levels = mpl.contourf(yp, xp, res_gyy, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax4.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

#   $G_{yz}$
ax5=plt.subplot(3,3,6)
ax5.text(0, 1.10,'(e) $G_{yz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax5.transAxes)


levels = mpl.contourf(yp, xp, res_gyz, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax5.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

#plt.xlabel('Easting coordinate y(km)')
#plt.ylabel('Northing coordinate x(km)')
mpl.m2km()


#   $G_{zz}$
ax6=plt.subplot(3,3,9)
ax6.text(0, 1.10,'(f) $G_{zz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax6.transAxes)


levels = mpl.contourf(yp, xp, res_gzz, regular_grid['shape'], 12, interp=True, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label(unit)

for i, sq in enumerate(full_model['projection']):
    y1, y2, x1, x2 = sq
    xs_project = [x1, x1, x2, x2, x1]
    ys_project = [y1, y2, y2, y1, y1]
    projection_style = '-r'
    ax6.plot(xs_project, ys_project, projection_style,linewidth = 1.0 )

plt.xlabel('Easting coordinate y(km)')
plt.ylabel('Northing coordinate x(km)')
mpl.m2km()

plt.savefig(file_name+'.eps', dpi=600)

# %% [markdown]
# ### THE HISTOGRAMS OF THE FTG RESIDUALS

# %%
file_name = '..\\figs\\HISTOGRAMS_FTG_RESIDUALS'


unit = 'Eotvos'
plt.figure(figsize=(12, 10))


#   $G_{xx}$
ax1=plt.subplot(3,3,1)
ax1.text(0.05, 0.90,'(a) $G_{xx}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax1.transAxes)


(mu_xx, sigma_xx) = norm.fit(res_gxx)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gxx, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_xx, sigma_xx)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
plt.xlabel('Residual $G_{xx}$ (Eotvos)')
plt.ylabel('Probability')
plt.title(r'$ \mu_{xx}=%.3f,\ \sigma_{xx}=%.3f$' %(mu_xx, sigma_xx))
plt.grid(True)



#   $G_{xy}$

ax2=plt.subplot(3,3,2)
ax2.text(0.05, 0.90,'(b) $G_{xy}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax2.transAxes)


(mu_xy, sigma_xy) = norm.fit(res_gxy)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gxy, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_xy, sigma_xy)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
#plt.xlabel('Residual $G_{xy}$ (Eotvos)')
plt.ylabel('Probability')
plt.title(r'$ \mu_{xy}=%.3f,\ \sigma_{xy}=%.3f$' %(mu_xy, sigma_xy))
plt.grid(True)

#   $G_{xz}$

ax3=plt.subplot(3,3,3)
ax3.text(0.05, 0.90,'(c) $G_{xz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax3.transAxes)


(mu_xz, sigma_xz) = norm.fit(res_gxz)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gxz, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_xz, sigma_xz)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
#plt.xlabel('Residual $G_xz$ (Eotvos)')
plt.ylabel('Probability')
plt.title(r'$ \mu_{xz}=%.3f,\ \sigma_{xz}=%.3f$' %(mu_xz, sigma_xz))
plt.grid(True)

#   $G_{yy}$
ax4=plt.subplot(3,3,5)
ax4.text(0.05, 0.90,'(d) $G_{yy}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax4.transAxes)


(mu_yy, sigma_yy) = norm.fit(res_gyy)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gyy, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_yy, sigma_yy)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
plt.xlabel('Residual $G_{yy}$ (Eotvos)')
plt.ylabel('Probability')
plt.title(r'$ \mu_{yy}=%.3f,\ \sigma_{yy}=%.3f$' %(mu_yy, sigma_yy))
plt.grid(True)


#   $G_{yz}$
ax5=plt.subplot(3,3,6)
ax5.text(0.05, 0.90,'(e) $G_{yz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax5.transAxes)


(mu_yz, sigma_yz) = norm.fit(res_gyz)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gyz, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_yz, sigma_yz)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
#plt.xlabel('Residual   $G_xy$ (Eotvos))')
plt.ylabel('Probability')
plt.title(r'$ \mu_{yz}=%.3f,\ \sigma_{yz}=%.3f$' %(mu_yz, sigma_yz))
plt.grid(True)


#   $G_{zz}$
ax6=plt.subplot(3,3,9)
ax6.text(0.05, 0.90,'(f) $G_{zz}$ Residual',
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax6.transAxes)


(mu_zz, sigma_zz) = norm.fit(res_gzz)
# the histogram of the difference between the true and the estimated RTP
n_h, bins, patches = plt.hist(res_gzz, 120, normed=1, facecolor='blue', alpha=0.75)
# add a 'best fit' line
y_histogram = mlab.normpdf(bins, mu_zz, sigma_zz)
l_histogram = plt.plot(bins, y_histogram, 'r--', linewidth=2)
plt.xlabel('Residual  $G_(zz}$ (Eotvos)')
plt.ylabel('Probability')
plt.title(r'$ \mu_{zz}=%.3f,\ \sigma_{zz}=%.3f$' %(mu_zz, sigma_zz))
plt.grid(True)


plt.savefig(file_name+'.eps', dpi=600)

# %%
with open('reports\\report_%s.md' % notebook_name[:st.index(notebook_name,'.')], 'w') as f:
    f.write('# Saved Informations \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    f.write('\n\n'+header+'\n\n')
    
    f.write('\n\n Estimated means and standard deviations of the FTG \n\n')
    f.write('mu_{xx} =  %4.3f,     sigma_{xx} =  %4.3f   \n '     %(mu_xx, sigma_xx))
    f.write('mu_{xy} =  %4.3f,     sigma_{xy} =  %4.3f   \n '     %(mu_xy, sigma_xy))
    f.write('mu_{xz} =  %4.3f,     sigma_{xz} =  %4.3f   \n '     %(mu_xz, sigma_xz))
    f.write('mu_{yy} =  %4.3f,     sigma_{yy} =  %4.3f   \n '     %(mu_yy, sigma_yy))
    f.write('mu_{yz} =  %4.3f,     sigma_{yz} =  %4.3f   \n '     %(mu_yz, sigma_yz))
    f.write('mu_{zz} =  %4.3f,     sigma_{zz} =  %4.3f   \n '     %(mu_zz, sigma_zz))
    
    
    f.write("\nREGIONAL INFORMATION ADDED TO THE ORIGINAL DATA WAS: \n {} \n".format(Regional_Information))
    if Regional_Information is not None: 
        if 'CONSTANT' in Regional_Information:
            f.write('\n'+Regional_Information+'  =  %4.3f \n' %Regional)
        elif 'FIRST-ORDER POLYNOMIAL' in Regional_Information:
            f.write('\n'+Regional_Information+' with coefficients:   \n')
            for kk in coef_1th: f.write(str(kk) + '\n')
        elif 'SECOND-ORDER POLYNOMIAL'in Regional_Information:
            f.write( '\n '+Regional_Information+' with coefficients: \n' )
            for kk in coef_2th: f.write(str(kk) + '\n')
    else:
        f.write( '\n Data Without Regional Background \n')
